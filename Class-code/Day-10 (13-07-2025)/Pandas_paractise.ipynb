# %%
pip install pandas
# Out:
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.0 MB 2.4 MB/s eta 0:00:05
#    ------- -------------------------------- 2.1/11.0 MB 5.3 MB/s eta 0:00:02
#    ------------------------------ --------- 8.4/11.0 MB 14.1 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 14.3 MB/s eta 0:00:00
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd

# %%
fruits = ['apple', 'banana', 'cherry']
print(fruits)
# Out:
# ['apple', 'banana', 'cherry']

# %%
fruits_ser = pd.Series(fruits)

# %%
fruits_ser
# Out:
# 0     apple
# 1    banana
# 2    cherry
# dtype: object

# %%
labels = ['a','b','c']
fruits_ser = pd.Series(data=fruits,index=labels)

# %%
fruits_ser['a':'b']
# Out:
# a     apple
# b    banana
# dtype: object

# %%
# DataFrames
students = {'Roll_no': [101, 102, 103, 104, 105],
           'Name': ['Ali', 'Ahmad', 'Umer', 'Zubair', 'Tayyab'],
           'Subject': ['OOP', 'Database', 'Software Engineering', 'OS', 'Programing'],
           'Marks': [80, 87, 67, 56, 92]}

# %%
pd.Series(students)
# Out:
# Roll_no                            [101, 102, 103, 104, 105]
# Name                      [Ali, Ahmad, Umer, Zubair, Tayyab]
# Subject    [OOP, Database, Software Engineering, OS, Prog...
# Marks                                   [80, 87, 67, 56, 92]
# dtype: object

# %%
df = pd.DataFrame(students)
df
# Out:
#    Roll_no    Name               Subject  Marks
# 0      101     Ali                   OOP     80
# 1      102   Ahmad              Database     87
# 2      103    Umer  Software Engineering     67
# 3      104  Zubair                    OS     56
# 4      105  Tayyab            Programing     92

# %%
# Pass a list of column names
df[['Name','Subject', 'Roll_no']]
# Out:
#      Name               Subject  Roll_no
# 0     Ali                   OOP      101
# 1   Ahmad              Database      102
# 2    Umer  Software Engineering      103
# 3  Zubair                    OS      104
# 4  Tayyab            Programing      105

# %%
df['F/N'] = ['Imran', 'Hassan', 'Bilal', 'Karamat', 'Tahir']

# %%
df
# Out:
#    Roll_no    Name               Subject  Marks      F/N
# 0      101     Ali                   OOP     80    Imran
# 1      102   Ahmad              Database     87   Hassan
# 2      103    Umer  Software Engineering     67    Bilal
# 3      104  Zubair                    OS     56  Karamat
# 4      105  Tayyab            Programing     92    Tahir

# %%
# Remove Percentage Column
df.drop('F/N',axis=1)
# Out:
#    Roll_no    Name               Subject  Marks
# 0      101     Ali                   OOP     80
# 1      102   Ahmad              Database     87
# 2      103    Umer  Software Engineering     67
# 3      104  Zubair                    OS     56
# 4      105  Tayyab            Programing     92

# %%
df2 = df.drop('F/N',axis=1)

# %%
df2
# Out:
#    Roll_no    Name               Subject  Marks
# 0      101     Ali                   OOP     80
# 1      102   Ahmad              Database     87
# 2      103    Umer  Software Engineering     67
# 3      104  Zubair                    OS     56
# 4      105  Tayyab            Programing     92

# %%
df
# Out:
#    Roll_no    Name               Subject  Marks      F/N
# 0      101     Ali                   OOP     80    Imran
# 1      102   Ahmad              Database     87   Hassan
# 2      103    Umer  Software Engineering     67    Bilal
# 3      104  Zubair                    OS     56  Karamat
# 4      105  Tayyab            Programing     92    Tahir

# %%
df.drop('F/N', axis = 1, inplace = True)

# %%
df
# Out:
#    Roll_no    Name               Subject  Marks
# 0      101     Ali                   OOP     80
# 1      102   Ahmad              Database     87
# 2      103    Umer  Software Engineering     67
# 3      104  Zubair                    OS     56
# 4      105  Tayyab            Programing     92

# %%
df2 = df2.drop(3)

# %%
df2
# Out:
#    Roll_no    Name               Subject  Marks
# 0      101     Ali                   OOP     80
# 1      102   Ahmad              Database     87
# 2      103    Umer  Software Engineering     67
# 4      105  Tayyab            Programing     92

# %%
df2.reset_index()
# Out:
#    index  Roll_no    Name               Subject  Marks
# 0      0      101     Ali                   OOP     80
# 1      1      102   Ahmad              Database     87
# 2      2      103    Umer  Software Engineering     67
# 3      4      105  Tayyab            Programing     92

# %%
df.set_index('Roll_no', inplace  = True)

# %%
df
# Out:
#            Name               Subject  Marks
# Roll_no
# 101         Ali                   OOP     80
# 102       Ahmad              Database     87
# 103        Umer  Software Engineering     67
# 104      Zubair                    OS     56
# 105      Tayyab            Programing     92

# %%
df.drop(101)
# Out:
#            Name               Subject  Marks
# Roll_no
# 102       Ahmad              Database     87
# 103        Umer  Software Engineering     67
# 104      Zubair                    OS     56
# 105      Tayyab            Programing     92

# %%
### loc, iloc
df
# Out:
#            Name               Subject  Marks
# Roll_no
# 101         Ali                   OOP     80
# 102       Ahmad              Database     87
# 103        Umer  Software Engineering     67
# 104      Zubair                    OS     56
# 105      Tayyab            Programing     92

# %%
df.loc[102]
# Out:
# Name          Ahmad
# Subject    Database
# Marks            87
# Name: 102, dtype: object

# %%
df.loc[102:104]
# Out:
#            Name               Subject  Marks
# Roll_no
# 102       Ahmad              Database     87
# 103        Umer  Software Engineering     67
# 104      Zubair                    OS     56

# %%
df.loc[102:104, ['Name', 'Marks']]
# Out:
#            Name  Marks
# Roll_no
# 102       Ahmad     87
# 103        Umer     67
# 104      Zubair     56

# %%
df.loc[102:104][['Name', 'Marks']]
# Out:
#            Name  Marks
# Roll_no
# 102       Ahmad     87
# 103        Umer     67
# 104      Zubair     56

# %%
df[['Name', 'Marks']].loc[102:104]
# Out:
#            Name  Marks
# Roll_no
# 102       Ahmad     87
# 103        Umer     67
# 104      Zubair     56

# %%
df
# Out:
#            Name               Subject  Marks
# Roll_no
# 101         Ali                   OOP     80
# 102       Ahmad              Database     87
# 103        Umer  Software Engineering     67
# 104      Zubair                    OS     56
# 105      Tayyab            Programing     92

# %%
df.iloc[2:5, 0:2]
# Out:
#            Name               Subject
# Roll_no
# 103        Umer  Software Engineering
# 104      Zubair                    OS
# 105      Tayyab            Programing

# %%
df_temp = df[df['Marks'] > 80]

# %%
df_temp
# Out:
#            Name     Subject  Marks
# Roll_no
# 102       Ahmad    Database     87
# 105      Tayyab  Programing     92

# %%
df_water = pd.read_csv('water_potability (1).csv')
df_water.head()
# Out:
#          ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0       NaN  204.890455  20791.318981     7.300212  368.516441    564.308654
# 1  3.716080  129.422921  18630.057858     6.635246         NaN    592.885359
# 2  8.099124  224.236259  19909.541732     9.275884         NaN    418.606213
# 3  8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 4  9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       10.379783        86.990970   2.963135           0
# 1       15.180013        56.329076   4.500656           0
# 2       16.868637        66.420093   3.055934           0
# 3       18.436524       100.341674   4.628771           0
# 4       11.558279        31.997993   4.075075           0

# %%
df_water.head(10)
# Out:
#           ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0        NaN  204.890455  20791.318981     7.300212  368.516441    564.308654
# 1   3.716080  129.422921  18630.057858     6.635246         NaN    592.885359
# 2   8.099124  224.236259  19909.541732     9.275884         NaN    418.606213
# 3   8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 4   9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
# 5   5.584087  188.313324  28748.687739     7.544869  326.678363    280.467916
# 6  10.223862  248.071735  28749.716544     7.513408  393.663396    283.651634
# 7   8.635849  203.361523  13672.091764     4.563009  303.309771    474.607645
# 8        NaN  118.988579  14285.583854     7.804174  268.646941    389.375566
# 9  11.180284  227.231469  25484.508491     9.077200  404.041635    563.885481
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# ...

# %%
df_water.head(30)
# Out:
#            ph    Hardness        Solids  Chloramines     Sulfate  \
# 0         NaN  204.890455  20791.318981     7.300212  368.516441
# 1    3.716080  129.422921  18630.057858     6.635246         NaN
# 2    8.099124  224.236259  19909.541732     9.275884         NaN
# 3    8.316766  214.373394  22018.417441     8.059332  356.886136
# 4    9.092223  181.101509  17978.986339     6.546600  310.135738
# 5    5.584087  188.313324  28748.687739     7.544869  326.678363
# 6   10.223862  248.071735  28749.716544     7.513408  393.663396
# 7    8.635849  203.361523  13672.091764     4.563009  303.309771
# 8         NaN  118.988579  14285.583854     7.804174  268.646941
# 9   11.180284  227.231469  25484.508491     9.077200  404.041635
# 10   7.360640  165.520797  32452.614409     7.550701  326.624353
# 11   7.974522  218.693300  18767.656682     8.110385         NaN
# 12   7.119824  156.704993  18730.813653     3.606036  282.344050
# ...

# %%
df_water.head(100)
# Out:
#           ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0        NaN  204.890455  20791.318981     7.300212  368.516441    564.308654
# 1   3.716080  129.422921  18630.057858     6.635246         NaN    592.885359
# 2   8.099124  224.236259  19909.541732     9.275884         NaN    418.606213
# 3   8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 4   9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
# ..       ...         ...           ...          ...         ...           ...
# 95  6.140878  197.876090  26687.874483     7.587196  329.231853    548.072761
# 96  7.077874  220.670540  23873.378210     6.181840  341.987234    333.050786
# 97  5.488314  135.802362  21485.153195     8.187416  280.603287    441.331137
# 98  7.205559  120.327615  24627.867560     6.202469  289.768697    418.433290
# 99  9.177870  163.274828  20868.331219     7.726040  320.421432    426.994393
#
# ...

# %%
df_water.tail()
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362         NaN
# 3273  9.419510  175.762646  33155.578218     7.350233         NaN
# 3274  5.126763  230.603758  11983.869376     6.303357         NaN
# 3275  7.874671  195.102299  17404.177061     7.509306         NaN
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 3271    526.424171       13.894419        66.687695   4.435821           1
# 3272    392.449580       19.903225              NaN   2.798243           1
# 3273    432.044783       11.039070        69.845400   3.298875           1
# 3274    402.883113       11.168946        77.488213   4.708658           1
# 3275    327.459760       16.140368        78.698446   2.309149           1

# %%
df_water.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3276 entries, 0 to 3275
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               2785 non-null   float64
#  1   Hardness         3276 non-null   float64
#  2   Solids           3276 non-null   float64
#  3   Chloramines      3276 non-null   float64
#  4   Sulfate          2495 non-null   float64
#  5   Conductivity     3276 non-null   float64
#  6   Organic_carbon   3276 non-null   float64
#  7   Trihalomethanes  3114 non-null   float64
#  8   Turbidity        3276 non-null   float64
#  9   Potability       3276 non-null   int64
# dtypes: float64(9), int64(1)
# memory usage: 256.1 KB

# %%
df_water.describe()
# Out:
#                 ph     Hardness        Solids  Chloramines      Sulfate  \
# count  2785.000000  3276.000000   3276.000000  3276.000000  2495.000000
# mean      7.080795   196.369496  22014.092526     7.122277   333.775777
# std       1.594320    32.879761   8768.570828     1.583085    41.416840
# min       0.000000    47.432000    320.942611     0.352000   129.000000
# 25%       6.093092   176.850538  15666.690297     6.127421   307.699498
# 50%       7.036752   196.967627  20927.833607     7.130299   333.073546
# 75%       8.062066   216.667456  27332.762127     8.114887   359.950170
# max      14.000000   323.124000  61227.196008    13.127000   481.030642
#
#        Conductivity  Organic_carbon  Trihalomethanes    Turbidity   Potability
# count   3276.000000     3276.000000      3114.000000  3276.000000  3276.000000
# mean     426.205111       14.284970        66.396293     3.966786     0.390110
# std       80.824064        3.308162        16.175008     0.780382     0.487849
# ...

# %%
df_water.head()
# Out:
#          ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0       NaN  204.890455  20791.318981     7.300212  368.516441    564.308654
# 1  3.716080  129.422921  18630.057858     6.635246         NaN    592.885359
# 2  8.099124  224.236259  19909.541732     9.275884         NaN    418.606213
# 3  8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 4  9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       10.379783        86.990970   2.963135           0
# 1       15.180013        56.329076   4.500656           0
# 2       16.868637        66.420093   3.055934           0
# 3       18.436524       100.341674   4.628771           0
# 4       11.558279        31.997993   4.075075           0

# %%
df_water.isna().sum()
# Out:
# ph                 491
# Hardness             0
# Solids               0
# Chloramines          0
# Sulfate            781
# Conductivity         0
# Organic_carbon       0
# Trihalomethanes    162
# Turbidity            0
# Potability           0
# dtype: int64

# %%
print(df_water.isna().sum().sum())
# Out:
# 1434

# %%
# to fill in empty values
df_filled = df_water.fillna(df_water.mean())
df_filled
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 0     7.080795  204.890455  20791.318981     7.300212  368.516441
# 1     3.716080  129.422921  18630.057858     6.635246  333.775777
# 2     8.099124  224.236259  19909.541732     9.275884  333.775777
# 3     8.316766  214.373394  22018.417441     8.059332  356.886136
# 4     9.092223  181.101509  17978.986339     6.546600  310.135738
# ...        ...         ...           ...          ...         ...
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362  333.775777
# 3273  9.419510  175.762646  33155.578218     7.350233  333.775777
# 3274  5.126763  230.603758  11983.869376     6.303357  333.775777
# 3275  7.874671  195.102299  17404.177061     7.509306  333.775777
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       564.308654       10.379783        86.990970   2.963135           0
# ...
